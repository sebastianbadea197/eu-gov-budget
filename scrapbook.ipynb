# %%
import xml.etree.ElementTree as ET
import pandas as pd
from lxml import etree

# %%
def parse_large_xml(file_path, target_elements):
    """
    Parse a large XML file by iteratively processing elements
    
    Parameters:
    file_path (str): Path to the XML file
    target_elements (list): List of element tags to extract
    
    Returns:
    list: Extracted data
    """
    data = []
    
    # Create iterative parser
    context = etree.iterparse(file_path, events=('end',), tag=target_elements)
    
    for event, elem in context:
        # Extract data from the element
        item = {}
        for child in elem:
            item[child.tag] = child.text
        
        data.append(item)
        
        # Clear element to free memory
        elem.clear()
        
    return data

def convert_df_to_nested_dict(df):
    """
    Convert DataFrame to nested dictionary with proper chapter hierarchy
    """
    nested_dict = {}
    
    for _, row in df.iterrows():
        capitol = row['CAPITOL']
        subcapitol = row['SUBCAPITOL'] if pd.notna(row['SUBCAPITOL']) else ''
        
        # Initialize capitol if it doesn't exist
        if capitol not in nested_dict:
            nested_dict[capitol] = {}
            
        # Initialize subcapitol if it doesn't exist
        if subcapitol not in nested_dict[capitol]:
            nested_dict[capitol][subcapitol] = {
                'paragraf': row['PARAGRAF'] if pd.notna(row['PARAGRAF']) else '',
                'grupa': row['GRUPA'] if pd.notna(row['GRUPA']) else '',
                'denumire': row['DENUMIRE'],
                'program_2025': row['PROGRAM_2025'],
                'estimari2026': row['ESTIMARI2026'],
                'estimari2027': row['ESTIMARI2027'],
                'estimari2028': row['ESTIMARI2028']
            }
    
    return nested_dict



def get_romanian_budget(file_path, target_elements):
    df = pd.DataFrame(parse_large_xml(file_path, target_elements))
    df.drop(['TITLU_RAPORT', 'ANEXA', 'COD_ORDONATOR', 'ORDONATOR'], axis=1, inplace=True)

    return df

# %%
file_path = 'anexa1_bs_2025.xml'
target_elements = ['G_TITLU_RAPORT']  # Adjust based on your XML structure

df = get_romanian_budget(file_path, target_elements)
# Convert the DataFrame to nested dictionary
budget_dict = convert_df_to_nested_dict(df)

# Example usage:
# Get all subcapitols for a specific capitol
print("Subcapitols for capitol '6501':")
print(budget_dict['6501'].keys())

# Get details for a specific subcapitol
print("\nDetails for capitol '6501', subcapitol '01':")
print(budget_dict['6501']['01'])
# Out:
# Subcapitols for capitol '6501':
# dict_keys(['', '  ', '01', '02', '03', '04', '05', '06', '07', '11', '13', '50'])
#
# Details for capitol '6501', subcapitol '01':
# {'paragraf': '', 'grupa': '', 'denumire': ' Administratie centrala', 'program_2025': None, 'estimari2026': None, 'estimari2027': None, 'estimari2028': None}

# %%
budget_dict.keys()
# Out:
# dict_keys(['0001', '0002', '0003', '0004', '0005', '0101', '0201', '0300', '0301', '0401', '0500', '0501', '0700', '0701', '1000', '1001', '1101', '1201', '1401', '1601', '1700', '1701', '2000', '2001', '2101', '2900', '3000', '3001', '3101', '3300', '3301', '3401', '3501', '3601', '3900', '3901', '4501', '4801', '4901', '5001', '5100', '5101', '5301', '5401', '5501', '5601', '6000', '6001', '6101', '6500', '6501', '6601', '6701', '6801', '7000', '7001', '7401', '8000', '8001', '8101', '8201', '8301', '8401', '8501', '8601', '8701', '9901'])

# %%
budget_dict
# Out:
# {'0001': {'01': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'VENITURI - TOTAL',
#    'program_2025': '357.353.033',
#    'estimari2026': '349.169.360',
#    'estimari2027': '349.399.128',
#    'estimari2028': '367.798.364'}},
#  '0002': {'01': {'paragraf': '  ',
#    'grupa': '',
#    'denumire': 'I.VENITURI CURENTE',
#    'program_2025': '278.999.496',
#    'estimari2026': '296.761.619',
#    'estimari2027': '317.534.856',
#    'estimari2028': '339.093.921'}},
#  '0003': {'01': {'paragraf': '  ',
#    'grupa': '',
#    'denumire': 'A.VENITURI FISCALE',
#    'program_2025': '234.103.618',
#    'estimari2026': '251.711.677',
#    'estimari2027': '270.005.482',
#    'estimari2028': '289.075.837'}},
#  '0004': {'01': {'paragraf': '  ',
#    'grupa': '',
#    'denumire': 'A1.IMPOZIT PE VENIT, PROFIT SI CASTIGURI DIN CAPITAL',
#    'program_2025': '60.729.767',
#    'estimari2026': '65.390.577',
#    'estimari2027': '69.551.838',
#    'estimari2028': '73.713.645'}},
#  '0005': {'01': {'paragraf': '  ',
#    'grupa': '',
#    'denumire': 'A11.IMPOZIT PE VENIT, PROFIT SI CASTIGURI DIN CAPITAL DE LA PERSOANE JURIDICE',
#    'program_2025': '44.654.554',
#    'estimari2026': '48.945.383',
#    'estimari2027': '52.411.055',
#    'estimari2028': '55.879.628'}},
#  '0101': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'IMPOZIT PE PROFIT',
#    'program_2025': '41.160.812',
#    'estimari2026': '46.228.568',
#    'estimari2027': '49.629.181',
#    'estimari2028': '53.036.140'},
#   '01': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Impozit pe profit de la agentii economici',
#    'program_2025': '39.259.016',
#    'estimari2026': '44.104.350',
#    'estimari2027': '47.283.538',
#    'estimari2028': '50.527.169'},
#   '02': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Impozit pe profit de la bancile comerciale',
#    'program_2025': '3.254.672',
#    'estimari2026': '3.517.681',
#    'estimari2027': '3.775.336',
#    'estimari2028': '4.038.214'},
#   '03': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Sume redirectionate din impozitul pe profit (se scad)',
#    'program_2025': '-1.352.876',
#    'estimari2026': '-1.393.463',
#    'estimari2027': '-1.429.693',
#    'estimari2028': '-1.529.243'}},
#  '0201': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'ALTE IMPOZITE PE VENIT, PROFIT SI CASTIGURI DIN CAPITAL DE LA PERSOANE JURIDICE',
#    'program_2025': '3.493.742',
#    'estimari2026': '2.716.815',
#    'estimari2027': '2.781.874',
#    'estimari2028': '2.843.488'},
#   '03': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Impozit pe dividende datorat de persoane juridice',
#    'program_2025': '1.257.682',
#    'estimari2026': '1.288.974',
#    'estimari2027': '1.316.908',
#    'estimari2028': '1.343.363'},
#   '06': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Impozit pe venitul microintreprinderilor',
#    'program_2025': '2.291.623',
#    'estimari2026': '1.485.071',
#    'estimari2027': '1.523.683',
#    'estimari2028': '1.560.252'},
#   '49': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'Sume redirectionate din impozitul pe veniturile microintreprinderilor (se scad)',
#    'program_2025': '-55.563',
#    'estimari2026': '-57.230',
#    'estimari2027': '-58.717',
#    'estimari2028': '-60.127'}},
#  '0300': {'01': {'paragraf': '  ',
#    'grupa': '',
#    'denumire': 'A12.IMPOZIT PE VENIT, PROFIT SI CASTIGURI DIN CAPITAL DE LA PERSOANE FIZICE',
#    'program_2025': '14.740.391',
#    'estimari2026': '15.070.327',
#    'estimari2027': '15.730.170',
#    'estimari2028': '16.389.549'}},
#  '0301': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'IMPOZIT PE VENIT',
#    'program_2025': '56.046.811',
#    'estimari2026': '60.317.954',
#    'estimari2027': '64.282.659',
#    'estimari2028': '68.287.912'},
#   '02': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Impozit pe venituri din salarii',
#    'program_2025': '36.569.117',
#    'estimari2026': '39.794.021',
#    'estimari2027': '42.747.063',
#    'estimari2028': '45.735.551'},
#   '03': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Impozit pe venituri din cedarea folosintei bunurilor',
#    'program_2025': '434.658',
#    'estimari2026': '469.770',
#    'estimari2027': '504.201',
#    'estimari2028': '539.290'},
#   '04': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Impozit pe venituri din dividende',
#    'program_2025': '7.355.120',
#    'estimari2026': '7.575.774',
#    'estimari2027': '7.772.744',
#    'estimari2028': '7.959.289'},
#   '05': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Impozit pe venituri din dobanzi',
#    'program_2025': '930.188',
#    'estimari2026': '960.885',
#    'estimari2027': '989.711',
#    'estimari2028': '1.019.402'},
#   '06': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Impozit pe venituri din pensii',
#    'program_2025': '5.092.718',
#    'estimari2026': '5.504.258',
#    'estimari2027': '5.907.423',
#    'estimari2028': '6.318.757'},
#   '07': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Impozit pe veniturile din premii',
#    'program_2025': '39.483',
#    'estimari2026': '40.786',
#    'estimari2027': '42.010',
#    'estimari2028': '43.270'},
#   '09': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Impozit pe venituri din transferul titlurilor de valoare',
#    'program_2025': '46.570',
#    'estimari2026': '48.107',
#    'estimari2027': '49.550',
#    'estimari2028': '51.037'},
#   '11': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Impozit pe venituri din valorificarea drepturilor de proprietate intelectuala',
#    'program_2025': '111.687',
#    'estimari2026': '120.856',
#    'estimari2027': '130.199',
#    'estimari2028': '139.663'},
#   '16': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Impozit pe venituri din activitati desfasurate in baza contractelor/ conventiilor civile incheiate potrivit Codului civil precum si a contractelor de agent',
#    'program_2025': '2.254',
#    'estimari2026': '2.440',
#    'estimari2027': '2.628',
#    'estimari2028': '2.819'},
#   '18': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Impozitul pe veniturile din transferul proprietatilor imobiliare din patrimoniul personal',
#    'program_2025': '793.695',
#    'estimari2026': '828.069',
#    'estimari2027': '861.339',
#    'estimari2028': '895.860'},
#   '19': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Sume virate pentru sponsorizarea entitatilor non-profit',
#    'program_2025': '-454.478',
#    'estimari2026': '-491.789',
#    'estimari2027': '-529.806',
#    'estimari2028': '-568.317'},
#   '21': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Impozit pe veniturile din arenda bunurilor agricole',
#    'program_2025': '183.311',
#    'estimari2026': '189.361',
#    'estimari2027': '195.041',
#    'estimari2028': '200.893'},
#   '22': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Impozit pe veniturile din jocuri de noroc',
#    'program_2025': '996.525',
#    'estimari2026': '1.029.410',
#    'estimari2027': '1.060.292',
#    'estimari2028': '1.092.101'},
#   '23': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Impozit pe venitul realizat  de persoana fizica dintr-o asociere cu o persoana juridica, contribuabil potrivit titlului II-impozit pe profit, care nu genereaza o persoana juridica',
#    'program_2025': '668',
#    'estimari2026': '688',
#    'estimari2027': '706',
#    'estimari2028': '723'},
#   '24': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Impozit pe veniturile realizate de persoana fizica dintr-o asociere cu o persoana juridica, contribuabil potrivit titlului III- impozitul pe veniturile microintreprinderilor, care nu genereaza o persoana juridica',
#    'program_2025': '726',
#    'estimari2026': '747',
#    'estimari2027': '767',
#    'estimari2028': '785'},
#   '26': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Impozitul pe veniturile din activitati independente realizate in baza contractelor de activitate sportiva',
#    'program_2025': '122.832',
#    'estimari2026': '126.517',
#    'estimari2027': '129.807',
#    'estimari2028': '132.922'},
#   '27': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Plati anticipate in contul impozitului pe venit anual datorat pentru unele venituri din activitati independente, precum si pentru venituri din alte surse',
#    'program_2025': '15.212',
#    'estimari2026': '15.669',
#    'estimari2027': '16.076',
#    'estimari2028': '16.462'},
#   '50': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Impozit pe venituri din alte surse',
#    'program_2025': '291.634',
#    'estimari2026': '301.258',
#    'estimari2027': '310.296',
#    'estimari2028': '319.605'},
#   '51': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Impozit pe venit aferent declaratiei unice',
#    'program_2025': '3.470.242',
#    'estimari2026': '3.755.139',
#    'estimari2027': '4.045.428',
#    'estimari2028': '4.339.484'},
#   '60': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Regularizari',
#    'program_2025': '44.649',
#    'estimari2026': '45.988',
#    'estimari2027': '47.184',
#    'estimari2028': '48.316'}},
#  '0401': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'COTE SI SUME DEFALCATE DIN IMPOZITUL PE VENIT (SE SCAD)',
#    'program_2025': '-41.306.420',
#    'estimari2026': '-45.247.627',
#    'estimari2027': '-48.552.489',
#    'estimari2028': '-51.898.363'},
#   '01': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Cote defalcate din impozitul pe venit (se scad)',
#    'program_2025': '-41.306.420',
#    'estimari2026': '-45.247.627',
#    'estimari2027': '-48.552.489',
#    'estimari2028': '-51.898.363'}},
#  '0500': {'01': {'paragraf': '  ',
#    'grupa': '',
#    'denumire': 'A13. ALTE IMPOZITE PE VENIT, PROFIT SI CASTIGURI DIN CAPITAL',
#    'program_2025': '1.334.822',
#    'estimari2026': '1.374.867',
#    'estimari2027': '1.410.613',
#    'estimari2028': '1.444.468'}},
#  '0501': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'ALTE IMPOZITE PE VENIT, PROFIT SI CASTIGURI DIN CAPITAL',
#    'program_2025': '1.334.822',
#    'estimari2026': '1.374.867',
#    'estimari2027': '1.410.613',
#    'estimari2028': '1.444.468'},
#   '01': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Impozit pe veniturile realizate de persoanele nerezidente',
#    'program_2025': '1.334.822',
#    'estimari2026': '1.374.867',
#    'estimari2027': '1.410.613',
#    'estimari2028': '1.444.468'}},
#  '0700': {'01': {'paragraf': '  ',
#    'grupa': '',
#    'denumire': 'A3.IMPOZITE SI TAXE PE PROPRIETATE',
#    'program_2025': '1.047.211',
#    'estimari2026': '1.078.627',
#    'estimari2027': '1.106.671',
#    'estimari2028': '1.133.232'}},
#  '0701': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'IMPOZITE SI TAXE PE PROPRIETATE',
#    'program_2025': '1.047.211',
#    'estimari2026': '1.078.627',
#    'estimari2027': '1.106.671',
#    'estimari2028': '1.133.232'},
#   '04': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Impozit pe constructii',
#    'program_2025': '1.034.100',
#    'estimari2026': '1.065.123',
#    'estimari2027': '1.092.816',
#    'estimari2028': '1.119.044'},
#   '06': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'Impozitul special pe bunurile imobile si mobile de valoare mare',
#    'program_2025': '13.111',
#    'estimari2026': '13.504',
#    'estimari2027': '13.855',
#    'estimari2028': '14.188'}},
#  '1000': {'01': {'paragraf': '  ',
#    'grupa': '',
#    'denumire': 'A4.IMPOZITE SI TAXE PE BUNURI SI SERVICII',
#    'program_2025': '170.238.105',
#    'estimari2026': '182.985.164',
#    'estimari2027': '196.924.326',
#    'estimari2028': '211.637.623'}},
#  '1001': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'TAXA PE VALOAREA ADAUGATA',
#    'program_2025': '136.089.244',
#    'estimari2026': '148.182.499',
#    'estimari2027': '158.670.020',
#    'estimari2028': '169.370.127'}},
#  '1101': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'SUME DEFALCATE DIN TVA',
#    'program_2025': '-24.343.640',
#    'estimari2026': '-26.670.825',
#    'estimari2027': '-27.404.257',
#    'estimari2028': '-28.175.173'},
#   '01': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Sume defalcate din taxa pe valoarea adaugata pentru finantarea cheltuielilor descentralizate la nivelul judetelor (se scad)',
#    'program_2025': '-3.553.321',
#    'estimari2026': '-3.563.254',
#    'estimari2027': '-3.572.582',
#    'estimari2028': '-3.582.189'},
#   '02': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Sume defalcate din taxa pe valoarea adaugata pentru finantarea cheltuielilor descentralizate la nivelul comunelor, oraselor, municipiilor,sectoarelor si Municipiului Bucuresti (se scad)',
#    'program_2025': '-15.799.050',
#    'estimari2026': '-17.826.853',
#    'estimari2027': '-18.346.999',
#    'estimari2028': '-18.882.749'},
#   '05': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Sume defalcate din taxa pe valoarea adaugata pentru drumuri (se scad)',
#    'program_2025': '-850.000',
#    'estimari2026': '-880.000',
#    'estimari2027': '-900.000',
#    'estimari2028': '-950.000'},
#   '06': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Sume defalcate din taxa pe valoarea adaugata pentru echilibrarea bugetelor locale (se scad)',
#    'program_2025': '-3.203.965',
#    'estimari2026': '-3.409.847',
#    'estimari2027': '-3.590.797',
#    'estimari2028': '-3.763.258'},
#   '09': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Sume defalcate din  taxa pe valoare adaugata pentru finantarea invatamantului particular si a celui confesional  (se scad)',
#    'program_2025': '-937.304',
#    'estimari2026': '-990.871',
#    'estimari2027': '-993.879',
#    'estimari2028': '-996.977'}},
#  '1201': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'ALTE IMPOZITE SI TAXE GENERALE PE BUNURI  SI SERVICII',
#    'program_2025': '3.940.811',
#    'estimari2026': '2.889.402',
#    'estimari2027': '2.801.245',
#    'estimari2028': '2.868.473'},
#   '11': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'Taxa pe venituri suplimentare obtinute ca urmare a dereglementarii preturilor din sectorul gazelor naturale.',
#    'program_2025': '1.725.037',
#    'estimari2026': '1.776.788',
#    'estimari2027': '1.822.985',
#    'estimari2028': '1.866.736'},
#   '12': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'Taxa speciala pentru exploatarea resurselor naturale',
#    'program_2025': '94.379',
#    'estimari2026': '104.894',
#    'estimari2027': '107.622',
#    'estimari2028': '110.204'},
#   '13': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'Taxa pe monopolul din sectorul energiei electrice si a gazului metan',
#    'program_2025': '158.737',
#    'estimari2026': '163.499',
#    'estimari2027': '167.750',
#    'estimari2028': '171.776'},
#   '18': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Impozitul suplimentar din vanzarea terenurilor agricole situate in extravilan',
#    'program_2025': '4.165',
#    'estimari2026': '4.290',
#    'estimari2027': '4.402',
#    'estimari2028': '4.507'},
#   '21': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'Impozitul pe cifra de afaceri realizata de institutiile de credit',
#    'program_2025': '1.321.915',
#    'estimari2026': '680.786',
#    'estimari2027': '698.486',
#    'estimari2028': '715.250'},
#   '22': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'Impozit specific pe cifra de afaceri realizata de agentii economici din sectoarele petrol si gaze naturale',
#    'program_2025': '636.578',
#    'estimari2026': '159.145',
#    'estimari2027': None,
#    'estimari2028': None}},
#  '1401': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'ACCIZE',
#    'program_2025': '48.589.307',
#    'estimari2026': '52.515.784',
#    'estimari2027': '56.362.346',
#    'estimari2028': '60.286.880'}},
#  '1601': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'TAXE PE UTILIZAREA BUNURILOR, AUTORIZAREA UTILIZARII BUNURILOR SAU PE  DESFASURAREA DE ACTIVITATI',
#    'program_2025': '5.962.383',
#    'estimari2026': '6.068.304',
#    'estimari2027': '6.494.972',
#    'estimari2028': '7.287.316'},
#   '01': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Taxe pentru jocurile de noroc',
#    'program_2025': '5.265.833',
#    'estimari2026': '5.691.362',
#    'estimari2027': '6.108.231',
#    'estimari2028': '6.533.549'},
#   '03': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Taxe si tarife pentru eliberarea de licente si autorizatii de functionare',
#    'program_2025': '661.176',
#    'estimari2026': '340.506',
#    'estimari2027': '349.359',
#    'estimari2028': '715.487'},
#   '04': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Taxe pe activitatea de prospectiune, explorare si exploatare a resurselor minerale',
#    'program_2025': '34.904',
#    'estimari2026': '35.951',
#    'estimari2027': '36.885',
#    'estimari2028': '37.771'},
#   '50': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Alte taxe pe utilizarea bunurilor, autorizarea utilizarii bunurilor sau pe desfasurare de activitati',
#    'program_2025': '470',
#    'estimari2026': '485',
#    'estimari2027': '497',
#    'estimari2028': '509'}},
#  '1700': {'01': {'paragraf': '  ',
#    'grupa': '',
#    'denumire': 'A5.IMPOZIT PE COMERTUL EXTERIOR SI TRANZACTIILE INTERNATIONALE',
#    'program_2025': '2.088.535',
#    'estimari2026': '2.257.309',
#    'estimari2027': '2.422.647',
#    'estimari2028': '2.591.337'}},
#  '1701': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'VENITURI INCADRATE IN RESURSELE PROPRII ALE BUGETULUI UNIUNII EUROPENE',
#    'program_2025': '2.088.535',
#    'estimari2026': '2.257.309',
#    'estimari2027': '2.422.647',
#    'estimari2028': '2.591.337'},
#   '01': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Taxe vamale',
#    'program_2025': '2.088.535',
#    'estimari2026': '2.257.309',
#    'estimari2027': '2.422.647',
#    'estimari2028': '2.591.337'}},
#  '2000': {'01': {'paragraf': '  ',
#    'grupa': '',
#    'denumire': 'B.CONTRIBUTII DE ASIGURARI',
#    'program_2025': '18.079.565',
#    'estimari2026': '19.383.863',
#    'estimari2027': '20.699.766',
#    'estimari2028': '22.027.746'}},
#  '2001': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'CONTRIBUTIILE ANGAJATORILOR',
#    'program_2025': '9.881.448',
#    'estimari2026': '10.512.876',
#    'estimari2027': '11.143.184',
#    'estimari2028': '11.776.063'},
#   '05': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Varsaminte de la persoane juridice, pentru persoane cu handicap neincadrate',
#    'program_2025': '3.448.848',
#    'estimari2026': '3.552.313',
#    'estimari2027': '3.644.673',
#    'estimari2028': '3.732.146'},
#   '08': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Venituri din contributia asiguratorie pentru munca aferenta bugetului de stat',
#    'program_2025': '6.432.600',
#    'estimari2026': '6.960.563',
#    'estimari2027': '7.498.511',
#    'estimari2028': '8.043.917'}},
#  '2101': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'CONTRIBUTIILE ASIGURATILOR',
#    'program_2025': '8.198.117',
#    'estimari2026': '8.870.987',
#    'estimari2027': '9.556.582',
#    'estimari2028': '10.251.683'},
#   '50': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Alte contributii pentru asigurari sociale datorate de asigurati',
#    'program_2025': '8.198.117',
#    'estimari2026': '8.870.987',
#    'estimari2027': '9.556.582',
#    'estimari2028': '10.251.683'}},
#  '2900': {'01': {'paragraf': '  ',
#    'grupa': '',
#    'denumire': 'C.VENITURI NEFISCALE',
#    'program_2025': '26.816.313',
#    'estimari2026': '25.666.079',
#    'estimari2027': '26.829.608',
#    'estimari2028': '27.990.338'}},
#  '3000': {'01': {'paragraf': '  ',
#    'grupa': '',
#    'denumire': 'C1.VENITURI DIN PROPRIETATE',
#    'program_2025': '21.562.235',
#    'estimari2026': '22.258.985',
#    'estimari2027': '23.277.186',
#    'estimari2028': '24.291.366'}},
#  '3001': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'VENITURI DIN PROPRIETATE',
#    'program_2025': '15.670.667',
#    'estimari2026': '16.190.670',
#    'estimari2027': '17.051.095',
#    'estimari2028': '17.915.849'},
#   '01': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Varsaminte din profitul net al regiilor autonome',
#    'program_2025': '349.668',
#    'estimari2026': '360.158',
#    'estimari2027': '369.522',
#    'estimari2028': '378.390'},
#   '04': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Varsaminte din veniturile nete al Bancii Nationale  a Romaniei',
#    'program_2025': '3.857.529',
#    'estimari2026': '3.973.255',
#    'estimari2027': '4.076.560',
#    'estimari2028': '4.174.397'},
#   '05': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Venituri din concesiuni si inchirieri',
#    'program_2025': '2.480.910',
#    'estimari2026': '2.555.338',
#    'estimari2027': '2.621.776',
#    'estimari2028': '2.684.699'},
#   '08': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Venituri din dividende',
#    'program_2025': '8.000.621',
#    'estimari2026': '8.240.640',
#    'estimari2027': '8.844.233',
#    'estimari2028': '9.460.060'},
#   '11': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'Venituri din vanzarea certificatelor de emisii  de gaze cu efect de sera',
#    'program_2025': '981.739',
#    'estimari2026': '1.061.073',
#    'estimari2027': '1.138.792',
#    'estimari2028': '1.218.086'},
#   '50': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Alte venituri din proprietate',
#    'program_2025': '200',
#    'estimari2026': '206',
#    'estimari2027': '212',
#    'estimari2028': '217'}},
#  '3101': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'VENITURI DIN DOBANZI',
#    'program_2025': '5.891.568',
#    'estimari2026': '6.068.315',
#    'estimari2027': '6.226.091',
#    'estimari2028': '6.375.517'},
#   '03': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Alte venituri din dobanzi',
#    'program_2025': '5.891.568',
#    'estimari2026': '6.068.315',
#    'estimari2027': '6.226.091',
#    'estimari2028': '6.375.517'}},
#  '3300': {'01': {'paragraf': '  ',
#    'grupa': '',
#    'denumire': 'C2.VANZARI DE BUNURI SI SERVICII',
#    'program_2025': '5.254.078',
#    'estimari2026': '3.407.094',
#    'estimari2027': '3.552.422',
#    'estimari2028': '3.698.972'}},
#  '3301': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'VENITURI DIN PRESTARI DE SERVICII SI ALTE ACTIVITATI',
#    'program_2025': '622.656',
#    'estimari2026': '641.336',
#    'estimari2027': '658.011',
#    'estimari2028': '673.804'},
#   '02': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Taxe consulare',
#    'program_2025': '145.408',
#    'estimari2026': '149.771',
#    'estimari2027': '153.665',
#    'estimari2028': '157.353'},
#   '08': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Venituri din prestari de servicii',
#    'program_2025': '271.613',
#    'estimari2026': '279.761',
#    'estimari2027': '287.035',
#    'estimari2028': '293.924'},
#   '09': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Taxe si alte venituri din protectia mediului',
#    'program_2025': '21.219',
#    'estimari2026': '21.856',
#    'estimari2027': '22.424',
#    'estimari2028': '22.962'},
#   '16': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Venituri din valorificarea produselor obtinute din activitatea proprie sau anexa',
#    'program_2025': '204',
#    'estimari2026': '210',
#    'estimari2027': '215',
#    'estimari2028': '221'},
#   '17': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Venituri din organizarea de cursuri de calificare si conversie profesionala, specializare si perfectionare',
#    'program_2025': '5.178',
#    'estimari2026': '5.333',
#    'estimari2027': '5.472',
#    'estimari2028': '5.603'},
#   '21': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'Venituri din contractele incheiate cu casele de asigurari sociale de sanatate',
#    'program_2025': '1.293',
#    'estimari2026': '1.331',
#    'estimari2027': '1.366',
#    'estimari2028': '1.399'},
#   '25': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Venituri din recuperarea cheltuielilor judiciare avansate de stat',
#    'program_2025': '81.297',
#    'estimari2026': '83.736',
#    'estimari2027': '85.913',
#    'estimari2028': '87.975'},
#   '26': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Venituri din despagubiri',
#    'program_2025': '82.995',
#    'estimari2026': '85.485',
#    'estimari2027': '87.708',
#    'estimari2028': '89.813'},
#   '29': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Tarife incasate pentru emiterea unei solutii fiscale individuale anticipate si pentru emiterea sau modificarea unui acord de pret in avans',
#    'program_2025': '2.566',
#    'estimari2026': '2.643',
#    'estimari2027': '2.712',
#    'estimari2028': '2.777'},
#   '50': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Alte venituri din prestari de servicii si alte activitati',
#    'program_2025': '10.883',
#    'estimari2026': '11.210',
#    'estimari2027': '11.501',
#    'estimari2028': '11.777'}},
#  '3401': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'VENITURI DIN TAXE ADMINISTRATIVE, ELIBERARI PERMISE',
#    'program_2025': '1.561',
#    'estimari2026': '1.608',
#    'estimari2027': '1.650',
#    'estimari2028': '1.689'},
#   '01': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Venituri din taxe pentru eliberari de permise si certificate',
#    'program_2025': '199',
#    'estimari2026': '205',
#    'estimari2027': '210',
#    'estimari2028': '215'},
#   '50': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Alte venituri din taxe administrative, eliberari permise',
#    'program_2025': '1.362',
#    'estimari2026': '1.403',
#    'estimari2027': '1.440',
#    'estimari2028': '1.474'}},
#  '3501': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'AMENZI, PENALITATI SI CONFISCARI',
#    'program_2025': '1.333.765',
#    'estimari2026': '1.437.377',
#    'estimari2027': '1.539.463',
#    'estimari2028': '1.644.063'},
#   '01': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Venituri din amenzi si alte sanctiuni aplicate potrivit dispozitiilor legale',
#    'program_2025': '790.206',
#    'estimari2026': '849.893',
#    'estimari2027': '908.949',
#    'estimari2028': '969.646'},
#   '02': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Penalitati pentru nedepunerea sau depunerea cu intarziere declaratiei de impozite si taxe',
#    'program_2025': '149',
#    'estimari2026': '161',
#    'estimari2027': '173',
#    'estimari2028': '185'},
#   '03': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Incasari din valorificarea bunurilor confiscate, abandonate si alte sume constatate odata cu confiscarea potrivit legii',
#    'program_2025': '80.592',
#    'estimari2026': '87.105',
#    'estimari2027': '93.485',
#    'estimari2028': '99.994'},
#   '04': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Majorari de intarziere pentru venituri nevarsate la termen',
#    'program_2025': '75',
#    'estimari2026': '81',
#    'estimari2027': '87',
#    'estimari2028': '93'},
#   '05': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Amenzi judiciare',
#    'program_2025': '20.939',
#    'estimari2026': '22.631',
#    'estimari2027': '24.289',
#    'estimari2028': '25.980'},
#   '06': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Incasari rezultate din valorificarea bunurilor confiscate ca urmare a savarsirii infractiunilor la regimul drogurilor si precursorilor',
#    'program_2025': '2.215',
#    'estimari2026': '2.394',
#    'estimari2027': '2.569',
#    'estimari2028': '2.748'},
#   '07': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'Penalitati datorate in cazul esalonarilor la plata',
#    'program_2025': '176.989',
#    'estimari2026': '191.291',
#    'estimari2027': '205.302',
#    'estimari2028': '219.598'},
#   '08': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'Penalitati de nedeclarare',
#    'program_2025': '244.807',
#    'estimari2026': '264.590',
#    'estimari2027': '283.970',
#    'estimari2028': '303.743'},
#   '50': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Alte amenzi, penalitati si confiscari',
#    'program_2025': '17.793',
#    'estimari2026': '19.231',
#    'estimari2027': '20.639',
#    'estimari2028': '22.076'}},
#  '3601': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'DIVERSE VENITURI',
#    'program_2025': '3.296.096',
#    'estimari2026': '1.326.773',
#    'estimari2027': '1.353.298',
#    'estimari2028': '1.379.416'},
#   '01': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Venituri din aplicarea prescriptiei extinctive',
#    'program_2025': '329.611',
#    'estimari2026': '339.499',
#    'estimari2027': '348.326',
#    'estimari2028': '356.686'},
#   '02': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Venituri din recuperarea cheltuielilor de judecata, imputatii si despagubiri',
#    'program_2025': '19.018',
#    'estimari2026': '19.588',
#    'estimari2027': '20.098',
#    'estimari2028': '20.580'},
#   '03': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Sume din recuperarea debitelor provenite din drepturile necuvenite',
#    'program_2025': '52.543',
#    'estimari2026': '54.119',
#    'estimari2027': '55.526',
#    'estimari2028': '56.859'},
#   '11': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Venituri din ajutoare de stat recuperate',
#    'program_2025': '2.123.302',
#    'estimari2026': '127.001',
#    'estimari2027': '130.303',
#    'estimari2028': '133.430'},
#   '14': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Venituri din recuperarea cheltuielilor efectuate in cursul procesului de executare silita',
#    'program_2025': '2.552',
#    'estimari2026': '2.629',
#    'estimari2027': '2.697',
#    'estimari2028': '2.762'},
#   '16': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Sume reprezentand ajutorul comunitar pentru furnizarea laptelui, produselor lactate si a fructelor in institutiile scolare',
#    'program_2025': '76.511',
#    'estimari2026': '78.806',
#    'estimari2027': '80.855',
#    'estimari2028': '82.795'},
#   '19': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Venituri din recuperarea creantelor fiscale',
#    'program_2025': '1.092',
#    'estimari2026': '1.125',
#    'estimari2027': '1.154',
#    'estimari2028': '1.182'},
#   '28': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Comision de risc aferent programului de stimulare a cupararii de autoturisme',
#    'program_2025': '14',
#    'estimari2026': '14',
#    'estimari2027': '15',
#    'estimari2028': '15'},
#   '32': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Comisionul de risc aferent programelor guvernamentale pentru IMM-uri',
#    'program_2025': '58.405',
#    'estimari2026': '60.157',
#    'estimari2027': '61.721',
#    'estimari2028': '63.203'},
#   '33': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'Taxa speciala datorata de agentiile/ autoritatile/ institutiile autonome',
#    'program_2025': '131.853',
#    'estimari2026': '121.808',
#    'estimari2027': '111.975',
#    'estimari2028': '103.663'},
#   '50': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Alte venituri',
#    'program_2025': '501.160',
#    'estimari2026': '521.991',
#    'estimari2027': '540.591',
#    'estimari2028': '558.203'},
#   '51': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Sume recuperate din contracte de prestari servicii, potrivit prevederilor OUG nr. 63/2020',
#    'program_2025': '35',
#    'estimari2026': '36',
#    'estimari2027': '37',
#    'estimari2028': '38'}},
#  '3900': {'01': {'paragraf': '  ',
#    'grupa': '',
#    'denumire': 'II.VENITURI DIN CAPITAL',
#    'program_2025': '350.000',
#    'estimari2026': '360.501',
#    'estimari2027': '369.871',
#    'estimari2028': '378.751'}},
#  '3901': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'VENITURI DIN VALORIFICAREA UNOR BUNURI',
#    'program_2025': '350.000',
#    'estimari2026': '360.501',
#    'estimari2027': '369.871',
#    'estimari2028': '378.751'},
#   '01': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Venituri din valorificarea unor bunuri ale institutiilor publice',
#    'program_2025': '10.428',
#    'estimari2026': '10.741',
#    'estimari2027': '11.020',
#    'estimari2028': '11.285'},
#   '03': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Venituri din vanzarea locuintelor construite din fondurile statului',
#    'program_2025': '37.662',
#    'estimari2026': '38.792',
#    'estimari2027': '39.801',
#    'estimari2028': '40.756'},
#   '06': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Venituri obtinute in procesul de stingere a creantelor bugetare',
#    'program_2025': '265.919',
#    'estimari2026': '273.897',
#    'estimari2027': '281.018',
#    'estimari2028': '287.763'},
#   '07': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Venituri din vanzarea unor bunuri apartinand domeniului privat al statului sau a unitatilor administativ-teritoriale',
#    'program_2025': '439',
#    'estimari2026': '452',
#    'estimari2027': '464',
#    'estimari2028': '475'},
#   '08': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Venituri obtinute in procesul de cesiune a creantelor fiscale',
#    'program_2025': '959',
#    'estimari2026': '988',
#    'estimari2027': '1.013',
#    'estimari2028': '1.038'},
#   '09': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Venituri rezultate din garantiile acordate si platite institutiilor de credit in cadrul programului "Prima casa/Noua casa"',
#    'program_2025': '8.770',
#    'estimari2026': '9.033',
#    'estimari2027': '9.268',
#    'estimari2028': '9.490'},
#   '13': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Venituri din recuperarea garantiilor aferente Programului de sustinere a intreprinderilor mci si mijlocii - IMM INVEST ROMANIA',
#    'program_2025': '17.128',
#    'estimari2026': '17.642',
#    'estimari2027': '18.100',
#    'estimari2028': '18.535'},
#   '15': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Venituri din recuperarea garantiilor aferente Programului de sustinere a intreprinderilor mici si mijlocii "IMM LEASING DE ECHIPAMENTE SI UTILAJE"',
#    'program_2025': '24',
#    'estimari2026': '25',
#    'estimari2027': '25',
#    'estimari2028': '26'},
#   '16': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Venituri din recuperarea garantiilor acordate din bugetul de stat',
#    'program_2025': '67',
#    'estimari2026': '69',
#    'estimari2027': '70',
#    'estimari2028': '72'},
#   '50': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Alte venituri din valorificarea unor bunuri',
#    'program_2025': '8.604',
#    'estimari2026': '8.862',
#    'estimari2027': '9.092',
#    'estimari2028': '9.311'}},
#  '4501': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'SUME PRIMITE DE LA UE / ALTI DONATORI IN CONTUL PLATILOR EFECTUATE SI PREFINANTARI',
#    'program_2025': '43.447.636',
#    'estimari2026': '35.042.749',
#    'estimari2027': '31.494.401',
#    'estimari2028': '28.325.692'}},
#  '4801': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'SUME PRIMITE DE LA UE/ALTI DONATORI IN CONTUL PLATILOR EFECTUATE SI PREFINANTARI AFERENTE CADRULUI FINANCIAR 2014-2020',
#    'program_2025': '7.701.609',
#    'estimari2026': '1.029',
#    'estimari2027': None,
#    'estimari2028': None}},
#  '4901': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'SUME AFERENTE ASISTENTEI FINANCIARE NERAMBURSABILE ALOCATE PENTRU PNRR',
#    'program_2025': '26.854.292',
#    'estimari2026': '17.003.462',
#    'estimari2027': None,
#    'estimari2028': None},
#   '02': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Sume rambursate din PNRR',
#    'program_2025': '26.854.292',
#    'estimari2026': '17.003.462',
#    'estimari2027': None,
#    'estimari2028': None}},
#  '5001': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'CHELTUIELI - BUGET DE STAT',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '  ': {'paragraf': '  ',
#    'grupa': '01',
#    'denumire': 'CHELTUIELI CURENTE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '5100': {'01': {'paragraf': '  ',
#    'grupa': '',
#    'denumire': 'Partea I-a SERVICII PUBLICE GENERALE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '5101': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'AUTORITATI PUBLICE SI ACTIUNI EXTERNE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '  ': {'paragraf': '  ',
#    'grupa': '01',
#    'denumire': 'CHELTUIELI CURENTE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '01': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Autoritati executive si legislative',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '03': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Contributia la bugetul UE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '04': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Cofinantarea fondurilor primite de la Uniunea Europeana',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '5301': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'CERCETARE FUNDAMENTALA SI CERCETARE DEZVOLTARE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '  ': {'paragraf': '  ',
#    'grupa': '01',
#    'denumire': 'CHELTUIELI CURENTE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '01': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Cercetare fundamentala (de baza)',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '02': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Cercetare si dezvoltare pentru servicii publice generale',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '5401': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'ALTE SERVICII PUBLICE GENERALE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '  ': {'paragraf': '  ',
#    'grupa': '01',
#    'denumire': 'CHELTUIELI CURENTE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '02': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Fond de rezerva bugetara la dispozitia Guvernului',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '11': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Asistenta nationala externa pentru dezvoltare',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '14': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Plata valorii de executare a garantiei in cadrul programului "Prima casa/Noua casa"',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '15': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'Sume rezultate din executarea garantiilor acordate din bugetul de stat',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '50': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Alte servicii publice generale',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '5501': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'TRANZACTII PRIVIND DATORIA PUBLICA SI IMPRUMUTURI',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '  ': {'paragraf': '  ',
#    'grupa': '01',
#    'denumire': 'CHELTUIELI CURENTE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '5601': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'TRANSFERURI CU CARACTER GENERAL INTRE DIFERITE NIVELE ALE ADMINISTRATIEI',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '  ': {'paragraf': '  ',
#    'grupa': '01',
#    'denumire': 'CHELTUIELI CURENTE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '02': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Transferuri din bugetul de stat catre bugetul asigurarilor sociale de stat',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '04': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Transferuri din bugetul de stat catre bugetul fondului de asigurari sociale de sanatate',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '6000': {'01': {'paragraf': '  ',
#    'grupa': '',
#    'denumire': 'Partea a II-a APARARE,ORDINE PUBLICA SI SIGURANTA NATIONALA',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '6001': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'APARARE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '  ': {'paragraf': '  ',
#    'grupa': '01',
#    'denumire': 'CHELTUIELI CURENTE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '01': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Administratie centrala',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '02': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Aparare nationala',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '03': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Participarea la misiuni si operatiuni militare in afara teritoriului statului roman',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '25': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Cercetare si dezvoltare pentru aparare',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '50': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Alte cheltuieli in domeniul apararii',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '6101': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'ORDINE PUBLICA SI SIGURANTA NATIONALA',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '  ': {'paragraf': '  ',
#    'grupa': '01',
#    'denumire': 'CHELTUIELI CURENTE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '01': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Administratia centrala',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '03': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Ordine publica',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '04': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Siguranta nationala',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '05': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Protectie civila si protectia contra incendiilor',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '06': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Autoritati judecatoresti',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '07': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Penitenciare',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '10': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Structura de sprijin a procurorilor europeni delegati in Romania',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '25': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Cercetare si dezvoltare pentru ordine publica si siguranta nationala',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '50': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Alte cheltuieli in domeniul ordinii publice si sigurantei nationale',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '6500': {'01': {'paragraf': '  ',
#    'grupa': '',
#    'denumire': 'Partea a III-a CHELTUIELI SOCIAL CULTURALE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '6501': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'INVATAMANT',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '  ': {'paragraf': '  ',
#    'grupa': '01',
#    'denumire': 'CHELTUIELI CURENTE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '01': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Administratie centrala',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '02': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Servicii publice descentralizate',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '03': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Invatamant prescolar si primar',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '04': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Invatamant secundar',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '05': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Invatamant postliceal',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '06': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Invatamant superior',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '07': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Invatamant nedefinibil prin nivel',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '11': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Servicii auxiliare pentru educatie',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '13': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Invatamant anteprescolar',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '50': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Alte cheltuieli in domeniul invatamantului',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '6601': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'SANATATE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '  ': {'paragraf': '  ',
#    'grupa': '01',
#    'denumire': 'CHELTUIELI CURENTE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '01': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Administratia centrala',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '02': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Servicii publice descentralizate',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '04': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Servicii medicale in ambulator',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '06': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Servicii medicale in unitati sanitare cu paturi',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '08': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Servicii de sanatate publica',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '09': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Hematologie si securitate transfuzionala',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '10': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Cercetare aplicativa si dezvoltare experimentala in sanatate',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '50': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Alte cheltuieli in domeniul sanatatii',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '6701': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'CULTURA, RECREERE SI RELIGIE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '  ': {'paragraf': '  ',
#    'grupa': '01',
#    'denumire': 'CHELTUIELI CURENTE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '01': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Administratie centrala',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '02': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Servicii publice descentralizate',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '03': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Servicii culturale',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '05': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Servicii recreative si sportive',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '50': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Alte servicii in domeniile culturii, recreerii si religiei',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '6801': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'ASIGURARI SI ASISTENTA SOCIALA',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '  ': {'paragraf': '  ',
#    'grupa': '01',
#    'denumire': 'CHELTUIELI CURENTE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '01': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Administratie centrala',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '02': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Servicii publice descentralizate',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '03': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Pensii si ajutoare pentru batranete',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '05': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Asistenta sociala in caz de boli si invaliditati',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '06': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Asistenta sociala pentru familie si copii',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '08': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Ajutoare la trecerea in rezerva, retragere sau pensionare',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '09': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Ajutoare pentru urmasi',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '15': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Prevenirea excluderii sociale',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '50': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Alte cheltuieli in domeniul asigurarilor si asistentei sociale',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '7000': {'01': {'paragraf': '  ',
#    'grupa': '',
#    'denumire': 'Partea a IV-a SERVICII SI DEZVOLTARE PUBLICA, LOCUINTE, MEDIU SI APE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '7001': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'LOCUINTE, SERVICII SI DEZVOLTARE PUBLICA',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '  ': {'paragraf': '  ',
#    'grupa': '01',
#    'denumire': 'CHELTUIELI CURENTE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '03': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Locuinte',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '05': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Alimentare cu apa si amenajari hidrotehnice',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '50': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Alte servicii in domeniile locuintelor, serviciilor si dezvoltarii comunale',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '7401': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'PROTECTIA MEDIULUI',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '  ': {'paragraf': '  ',
#    'grupa': '01',
#    'denumire': 'CHELTUIELI CURENTE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '01': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Administratie centrala',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '03': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Reducerea si controlul poluarii',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '8000': {'01': {'paragraf': '  ',
#    'grupa': '',
#    'denumire': 'Partea a V-a ACTIUNI ECONOMICE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '8001': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'ACTIUNI GENERALE ECONOMICE, COMERCIALE SI DE MUNCA',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '  ': {'paragraf': '  ',
#    'grupa': '01',
#    'denumire': 'CHELTUIELI CURENTE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '01': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Actiuni generale economice si comerciale',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '8101': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'COMBUSTIBILI SI ENERGIE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '  ': {'paragraf': '  ',
#    'grupa': '01',
#    'denumire': 'CHELTUIELI CURENTE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '50': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Alte cheltuieli privind combustibili si energia',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '8201': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'INDUSTRIA EXTRACTIVA, PRELUCRATOARE SI CONSTRUCTII',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '  ': {'paragraf': '  ',
#    'grupa': '01',
#    'denumire': 'CHELTUIELI CURENTE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '50': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Alte cheltuieli in domeniul industriei',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '8301': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'AGRICULTURA, SILVICULTURA, PISCICULTURA SI VANATOARE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '  ': {'paragraf': '  ',
#    'grupa': '01',
#    'denumire': 'CHELTUIELI CURENTE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '01': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Administratie centrala',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '02': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Servicii publice descentralizate',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '03': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Agricultura',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '04': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Sivilcultura',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '50': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Alte cheltuieli in domeniul agriculturii, silviculturii, pisciculturii si vanatorii',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '8401': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'TRANSPORTURI',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '  ': {'paragraf': '  ',
#    'grupa': '01',
#    'denumire': 'CHELTUIELI CURENTE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '01': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Administratie centrala',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '03': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Transport rutier',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '04': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Transport feroviar',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '05': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Transport pe apa',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '06': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Transport aerian',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '50': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Alte cheltuieli in domeniul transporturilor',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '8501': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'COMUNICATII',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '  ': {'paragraf': '  ',
#    'grupa': '01',
#    'denumire': 'CHELTUIELI CURENTE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '01': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Comunicatii',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '8601': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'CERCETARE SI DEZVOLTARE IN DOMENIUL ECONOMIC',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '  ': {'paragraf': '  ',
#    'grupa': '01',
#    'denumire': 'CHELTUIELI CURENTE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '02': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Cercetare si dezvoltare in domeniul agriculturii, silviculturii, pisciculturii si vanatorii',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '03': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Cercetare si dezvoltare in domeniul combustibilului si energiei',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '8701': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'ALTE ACTIUNI ECONOMICE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '  ': {'paragraf': '  ',
#    'grupa': '01',
#    'denumire': 'CHELTUIELI CURENTE',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None},
#   '04': {'paragraf': '',
#    'grupa': '',
#    'denumire': ' Turism',
#    'program_2025': None,
#    'estimari2026': None,
#    'estimari2027': None,
#    'estimari2028': None}},
#  '9901': {'': {'paragraf': '',
#    'grupa': '',
#    'denumire': 'DEFICIT',
#    'program_2025': '-142.229.947',
#    'estimari2026': '-137.297.372',
#    'estimari2027': '-137.984.298',
#    'estimari2028': '-132.284.830'}}}

# %%
df[df['PARAGRAF'] == '01']
# Out:
#      CAPITOL SUBCAPITOL PARAGRAF GRUPA ARTICOL ALINEAT  \
# 312     5101         01       01  None    None    None
# 313     5101         01       01  None    None    None
# 522     6001         50       01  None    None    None
# 523     6001         50       01  None    None    None
# 575     6101         03       01  None    None    None
# 576     6101         03       01  None    None    None
# 691     6501         03       01  None    None    None
# 692     6501         03       01  None    None    None
# 697     6501         04       01  None    None    None
# 698     6501         04       01  None    None    None
# 707     6501         06       01  None    None    None
# 708     6501         06       01  None    None    None
# 780     6601         06       01  None    None    None
# 781     6601         06       01  None    None    None
# 839     6701         03       01  None    None    None
# 840     6701         03       01  None    None    None
# 855     6701         05       01  None    None    None
# 856     6701         05       01  None    None    None
# 924     6801         15       01  None    None    None
# 925     6801         15       01  None    None    None
# 1023    7001         03       01  None    None    None
# 1024    7001         03       01  None    None    None
# 1187    8001         01       01  None    None    None
# 1188    8001         01       01  None    None    None
# 1369    8401         03       01  None    None    None
# 1370    8401         03       01  None    None    None
# 1373    8401         04       01  None    None    None
# 1374    8401         04       01  None    None    None
#
#                                   DENUMIRE PROGRAM_2025 ESTIMARI2026  \
# 312            Administratia prezidentiala         None         None
# 313                    II.Credite bugetare       89.915         None
# 522           Structuri militare nationale         None         None
# 523                    II.Credite bugetare       48.389         None
# 575                                Politie         None         None
# 576                    II.Credite bugetare    8.762.874         None
# 691                   Invatamant prescolar         None         None
# 692                    II.Credite bugetare    7.759.670         None
# 697           Invatamant secundar inferior         None         None
# 698                    II.Credite bugetare    9.933.827         None
# 707                 Invatamant universitar         None         None
# 708                    II.Credite bugetare    1.022.337         None
# 780                       Spitale generale         None         None
# 781                    II.Credite bugetare      266.302         None
# 839           Biblioteci publice nationale         None         None
# 840                    II.Credite bugetare       28.745         None
# 855                                  Sport         None         None
# 856                    II.Credite bugetare      844.988         None
# 924                          Ajutor social         None         None
# 925                    II.Credite bugetare    4.767.796         None
# 1023    Dezvoltarea sistemului de locuinte         None         None
# 1024                   II.Credite bugetare    5.302.278         None
# 1187                Administratie centrala         None         None
# 1188                   II.Credite bugetare       23.705         None
# 1369                     Drumuri si poduri         None         None
# 1370                   II.Credite bugetare   19.479.291         None
# 1373              Transport pe cale ferata         None         None
# 1374                   II.Credite bugetare   16.374.604         None
#
#      ESTIMARI2027 ESTIMARI2028
# 312          None         None
# 313          None         None
# 522          None         None
# 523          None         None
# 575          None         None
# 576          None         None
# 691          None         None
# 692          None         None
# 697          None         None
# 698          None         None
# 707          None         None
# 708          None         None
# 780          None         None
# 781          None         None
# 839          None         None
# 840          None         None
# 855          None         None
# 856          None         None
# 924          None         None
# 925          None         None
# 1023         None         None
# 1024         None         None
# 1187         None         None
# 1188         None         None
# 1369         None         None
# 1370         None         None
# 1373         None         None
# 1374         None         None

# %%
df[df['PARAGRAF'].isnull()]
# Out:
#      CAPITOL SUBCAPITOL PARAGRAF GRUPA ARTICOL ALINEAT  \
# 0       0001         01     None  None    None    None
# 5       0101       None     None  None    None    None
# 6       0101         01     None  None    None    None
# 7       0101         02     None  None    None    None
# 8       0101         03     None  None    None    None
# ...      ...        ...      ...   ...     ...     ...
# 1446    8701       None     None  None    None    None
# 1447    8701       None     None  None    None    None
# 1457    8701         04     None  None    None    None
# 1458    8701         04     None  None    None    None
# 1459    9901       None     None  None    None    None
#
#                                                DENUMIRE  PROGRAM_2025  \
# 0                                      VENITURI - TOTAL   357.353.033
# 5                                     IMPOZIT PE PROFIT    41.160.812
# 6             Impozit pe profit de la agentii economici    39.259.016
# 7            Impozit pe profit de la bancile comerciale     3.254.672
# 8      Sume redirectionate din impozitul pe profit (...    -1.352.876
# ...                                                 ...           ...
# 1446                            I.Credite de angajament        26.803
# 1447                                II.Credite bugetare        26.803
# 1457                                             Turism          None
# 1458                                II.Credite bugetare        26.803
# 1459                                            DEFICIT  -142.229.947
#
#       ESTIMARI2026  ESTIMARI2027  ESTIMARI2028
# 0      349.169.360   349.399.128   367.798.364
# 5       46.228.568    49.629.181    53.036.140
# 6       44.104.350    47.283.538    50.527.169
# 7        3.517.681     3.775.336     4.038.214
# 8       -1.393.463    -1.429.693    -1.529.243
# ...            ...           ...           ...
# 1446        26.803        26.803        26.803
# 1447        26.803        26.803        26.803
# 1457          None          None          None
# 1458          None          None          None
# 1459  -137.297.372  -137.984.298  -132.284.830
#
# [354 rows x 11 columns]

# %%
context = etree.iterparse("anexa1_bs_2025.xml", events=('end',), tag="G_TITLU_RAPORT")

# %%
capitol: {
    subcapitol: {
        paragraf: 
        grupa: 
        articol: 
        alineat: 
        denumire: 
        program_2025: 
        estimari2026: 
        estimari2027: 
        estimari2028: 
    }
}

# %%
data = parse_large_xml("anexa1_bs_2025.xml", ["G_TITLU_RAPORT"])

# %%
list_of_chapters = []

for element in data:
    list_of_chapters.append([element['CAPITOL'], element['SUBCAPITOL']])
    print(element['CAPITOL'])
    print(element['SUBCAPITOL'])
# Out:
# 0001
# 01
# 0002
# 01
# 0003
# 01
# 0004
# 01
# 0005
# 01
# 0101
# None
# 0101
# 01
# 0101
# 02
# 0101
# 03
# 0201
# None
# 0201
# 03
# 0201
# 06
# 0201
# 49
# 0300
# 01
# 0301
# None
# 0301
# 02
# 0301
# 03
# 0301
# 04
# 0301
# 05
# 0301
# 06
# 0301
# 07
# 0301
# 09
# 0301
# 11
# 0301
# 16
# 0301
# 18
# 0301
# 19
# 0301
# 21
# 0301
# 22
# 0301
# 23
# 0301
# 24
# 0301
# 26
# 0301
# 27
# 0301
# 50
# 0301
# 51
# 0301
# 60
# 0401
# None
# 0401
# 01
# 0500
# 01
# 0501
# None
# 0501
# 01
# 0700
# 01
# 0701
# None
# 0701
# 04
# 0701
# 06
# 1000
# 01
# 1001
# None
# 1101
# None
# 1101
# 01
# 1101
# 02
# 1101
# 05
# 1101
# 06
# 1101
# 09
# 1201
# None
# 1201
# 11
# 1201
# 12
# 1201
# 13
# 1201
# 18
# 1201
# 21
# 1201
# 22
# 1401
# None
# 1601
# None
# 1601
# 01
# 1601
# 03
# 1601
# 04
# 1601
# 50
# 1700
# 01
# 1701
# None
# 1701
# 01
# 2000
# 01
# 2001
# None
# 2001
# 05
# 2001
# 08
# 2101
# None
# 2101
# 50
# 2900
# 01
# 3000
# 01
# 3001
# None
# 3001
# 01
# 3001
# 04
# 3001
# 05
# 3001
# 08
# 3001
# 11
# 3001
# 50
# 3101
# None
# 3101
# 03
# 3300
# 01
# 3301
# None
# 3301
# 02
# 3301
# 08
# 3301
# 09
# 3301
# 16
# 3301
# 17
# 3301
# 21
# 3301
# 25
# 3301
# 26
# 3301
# 29
# 3301
# 50
# 3401
# None
# 3401
# 01
# 3401
# 50
# 3501
# None
# 3501
# 01
# 3501
# 02
# 3501
# 03
# 3501
# 04
# 3501
# 05
# 3501
# 06
# 3501
# 07
# 3501
# 08
# 3501
# 50
# 3601
# None
# 3601
# 01
# 3601
# 02
# 3601
# 03
# 3601
# 11
# 3601
# 14
# 3601
# 16
# 3601
# 19
# 3601
# 28
# 3601
# 32
# 3601
# 33
# 3601
# 50
# 3601
# 51
# 3900
# 01
# 3901
# None
# 3901
# 01
# 3901
# 03
# 3901
# 06
# 3901
# 07
# 3901
# 08
# 3901
# 09
# 3901
# 13
# 3901
# 15
# 3901
# 16
# 3901
# 50
# 4501
# None
# 4801
# None
# 4901
# None
# 4901
# 02
# 5001
# None
# 5001
# None
# 5001
# None
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5001
#
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5100
# 01
# 5101
# None
# 5101
# None
# 5101
# None
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
#
# 5101
# 01
# 5101
# 01
# 5101
# 01
# 5101
# 01
# 5101
# 01
# 5101
# 01
# 5101
# 01
# 5101
# 01
# 5101
# 01
# 5101
# 01
# 5101
# 03
# 5101
# 03
# 5101
# 04
# 5101
# 04
# 5301
# None
# 5301
# None
# 5301
# None
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
#
# 5301
# 01
# 5301
# 01
# 5301
# 02
# 5301
# 02
# 5401
# None
# 5401
# None
# 5401
# None
# 5401
#
# 5401
#
# 5401
#
# 5401
#
# 5401
#
# 5401
#
# 5401
#
# 5401
#
# 5401
#
# 5401
#
# 5401
#
# 5401
#
# 5401
#
# 5401
#
# 5401
#
# 5401
#
# 5401
#
# 5401
#
# 5401
#
# 5401
#
# 5401
#
# 5401
# 02
# 5401
# 02
# 5401
# 11
# 5401
# 11
# 5401
# 14
# 5401
# 14
# 5401
# 15
# 5401
# 15
# 5401
# 50
# 5401
# 50
# 5501
# None
# 5501
# None
# 5501
# None
# 5501
#
# 5501
#
# 5501
#
# 5501
#
# 5501
#
# 5501
#
# 5501
#
# 5501
#
# 5501
#
# 5501
#
# 5501
#
# 5501
#
# 5501
#
# 5501
#
# 5501
#
# 5501
#
# 5501
#
# 5501
#
# 5601
# None
# 5601
# None
# 5601
# None
# 5601
#
# 5601
#
# 5601
#
# 5601
#
# 5601
#
# 5601
#
# 5601
# 02
# 5601
# 02
# 5601
# 04
# 5601
# 04
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6000
# 01
# 6001
# None
# 6001
# None
# 6001
# None
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
#
# 6001
# 01
# 6001
# 01
# 6001
# 02
# 6001
# 02
# 6001
# 03
# 6001
# 03
# 6001
# 25
# 6001
# 25
# 6001
# 50
# 6001
# 50
# 6001
# 50
# 6001
# 50
# 6001
# 50
# 6001
# 50
# 6101
# None
# 6101
# None
# 6101
# None
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
#
# 6101
# 01
# 6101
# 01
# 6101
# 03
# 6101
# 03
# 6101
# 03
# 6101
# 03
# 6101
# 03
# 6101
# 03
# 6101
# 03
# 6101
# 03
# 6101
# 04
# 6101
# 04
# 6101
# 05
# 6101
# 05
# 6101
# 06
# 6101
# 06
# 6101
# 07
# 6101
# 07
# 6101
# 10
# 6101
# 10
# 6101
# 25
# 6101
# 25
# 6101
# 50
# 6101
# 50
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6500
# 01
# 6501
# None
# 6501
# None
# 6501
# None
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
#
# 6501
# 01
# 6501
# 01
# 6501
# 02
# 6501
# 02
# 6501
# 03
# 6501
# 03
# 6501
# 03
# 6501
# 03
# 6501
# 03
# 6501
# 03
# 6501
# 04
# 6501
# 04
# 6501
# 04
# 6501
# 04
# 6501
# 04
# 6501
# 04
# 6501
# 04
# 6501
# 04
# 6501
# 05
# 6501
# 05
# 6501
# 06
# 6501
# 06
# 6501
# 06
# 6501
# 06
# 6501
# 07
# 6501
# 07
# 6501
# 07
# 6501
# 07
# 6501
# 07
# 6501
# 07
# 6501
# 11
# 6501
# 11
# 6501
# 11
# 6501
# 11
# 6501
# 11
# 6501
# 11
# 6501
# 13
# 6501
# 13
# 6501
# 50
# 6501
# 50
# 6601
# None
# 6601
# None
# 6601
# None
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
#
# 6601
# 01
# 6601
# 01
# 6601
# 02
# 6601
# 02
# 6601
# 04
# 6601
# 04
# 6601
# 04
# 6601
# 04
# 6601
# 06
# 6601
# 06
# 6601
# 06
# 6601
# 06
# 6601
# 06
# 6601
# 06
# 6601
# 08
# 6601
# 08
# 6601
# 09
# 6601
# 09
# 6601
# 10
# 6601
# 10
# 6601
# 50
# 6601
# 50
# 6601
# 50
# 6601
# 50
# 6701
# None
# 6701
# None
# 6701
# None
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
#
# 6701
# 01
# 6701
# 01
# 6701
# 02
# 6701
# 02
# 6701
# 03
# 6701
# 03
# 6701
# 03
# 6701
# 03
# 6701
# 03
# 6701
# 03
# 6701
# 03
# 6701
# 03
# 6701
# 03
# 6701
# 03
# 6701
# 03
# 6701
# 03
# 6701
# 03
# 6701
# 03
# 6701
# 03
# 6701
# 03
# 6701
# 05
# 6701
# 05
# 6701
# 05
# 6701
# 05
# 6701
# 05
# 6701
# 05
# 6701
# 50
# 6701
# 50
# 6801
# None
# 6801
# None
# 6801
# None
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
#
# 6801
# 01
# 6801
# 01
# 6801
# 02
# 6801
# 02
# 6801
# 03
# 6801
# 03
# 6801
# 05
# 6801
# 05
# 6801
# 05
# 6801
# 05
# 6801
# 06
# 6801
# 06
# 6801
# 08
# 6801
# 08
# 6801
# 09
# 6801
# 09
# 6801
# 15
# 6801
# 15
# 6801
# 15
# 6801
# 15
# 6801
# 15
# 6801
# 15
# 6801
# 15
# 6801
# 15
# 6801
# 50
# 6801
# 50
# 6801
# 50
# 6801
# 50
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7000
# 01
# 7001
# None
# 7001
# None
# 7001
# None
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
#
# 7001
# 03
# 7001
# 03
# 7001
# 03
# 7001
# 03
# 7001
# 05
# 7001
# 05
# 7001
# 05
# 7001
# 05
# 7001
# 50
# 7001
# 50
# 7401
# None
# 7401
# None
# 7401
# None
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
#
# 7401
# 01
# 7401
# 01
# 7401
# 03
# 7401
# 03
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8000
# 01
# 8001
# None
# 8001
# None
# 8001
# None
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
#
# 8001
# 01
# 8001
# 01
# 8001
# 01
# 8001
# 01
# 8001
# 01
# 8001
# 01
# 8001
# 01
# 8001
# 01
# 8001
# 01
# 8001
# 01
# 8001
# 01
# 8001
# 01
# 8001
# 01
# 8001
# 01
# 8001
# 01
# 8001
# 01
# 8001
# 01
# 8001
# 01
# 8101
# None
# 8101
# None
# 8101
# None
# 8101
#
# 8101
#
# 8101
#
# 8101
#
# 8101
#
# 8101
#
# 8101
#
# 8101
#
# 8101
#
# 8101
# 50
# 8101
# 50
# 8201
# None
# 8201
# None
# 8201
# None
# 8201
#
# 8201
#
# 8201
#
# 8201
#
# 8201
#
# 8201
#
# 8201
#
# 8201
#
# 8201
#
# 8201
#
# 8201
#
# 8201
#
# 8201
#
# 8201
#
# 8201
#
# 8201
# 50
# 8201
# 50
# 8301
# None
# 8301
# None
# 8301
# None
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
#
# 8301
# 01
# 8301
# 01
# 8301
# 02
# 8301
# 02
# 8301
# 03
# 8301
# 03
# 8301
# 03
# 8301
# 03
# 8301
# 03
# 8301
# 03
# 8301
# 03
# 8301
# 03
# 8301
# 03
# 8301
# 03
# 8301
# 03
# 8301
# 03
# 8301
# 04
# 8301
# 04
# 8301
# 50
# 8301
# 50
# 8401
# None
# 8401
# None
# 8401
# None
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
#
# 8401
# 01
# 8401
# 01
# 8401
# 03
# 8401
# 03
# 8401
# 03
# 8401
# 03
# 8401
# 04
# 8401
# 04
# 8401
# 04
# 8401
# 04
# 8401
# 04
# 8401
# 04
# 8401
# 05
# 8401
# 05
# 8401
# 06
# 8401
# 06
# 8401
# 06
# 8401
# 06
# 8401
# 50
# 8401
# 50
# 8501
# None
# 8501
# None
# 8501
# None
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
#
# 8501
# 01
# 8501
# 01
# 8601
# None
# 8601
# None
# 8601
# None
# 8601
#
# 8601
#
# 8601
#
# 8601
#
# 8601
#
# 8601
#
# 8601
#
# 8601
#
# 8601
#
# 8601
#
# 8601
#
# 8601
#
# 8601
# 02
# 8601
# 02
# 8601
# 03
# 8601
# 03
# 8701
# None
# 8701
# None
# 8701
# None
# 8701
#
# 8701
#
# 8701
#
# 8701
#
# 8701
#
# 8701
#
# 8701
#
# 8701
#
# 8701
#
# 8701
# 04
# 8701
# 04
# 9901
# None

# %%
# Example usage

# %%
df
# Out:
#      CAPITOL SUBCAPITOL PARAGRAF GRUPA ARTICOL ALINEAT  \
# 0       0001         01     None  None    None    None
# 1       0002         01           None    None    None
# 2       0003         01           None    None    None
# 3       0004         01           None    None    None
# 4       0005         01           None    None    None
# ...      ...        ...      ...   ...     ...     ...
# 1455    8701                        51    None    None
# 1456    8701                        51    None    None
# 1457    8701         04     None  None    None    None
# 1458    8701         04     None  None    None    None
# 1459    9901       None     None  None    None    None
#
#                                                DENUMIRE  PROGRAM_2025  \
# 0                                      VENITURI - TOTAL   357.353.033
# 1                                    I.VENITURI CURENTE   278.999.496
# 2                                    A.VENITURI FISCALE   234.103.618
# 3     A1.IMPOZIT PE VENIT, PROFIT SI CASTIGURI DIN C...    60.729.767
# 4     A11.IMPOZIT PE VENIT, PROFIT SI CASTIGURI DIN ...    44.654.554
# ...                                                 ...           ...
# 1455                            I.Credite de angajament        10.000
# 1456                                II.Credite bugetare        10.000
# 1457                                             Turism          None
# 1458                                II.Credite bugetare        26.803
# 1459                                            DEFICIT  -142.229.947
#
#       ESTIMARI2026  ESTIMARI2027  ESTIMARI2028
# 0      349.169.360   349.399.128   367.798.364
# 1      296.761.619   317.534.856   339.093.921
# 2      251.711.677   270.005.482   289.075.837
# 3       65.390.577    69.551.838    73.713.645
# 4       48.945.383    52.411.055    55.879.628
# ...            ...           ...           ...
# 1455        10.000        10.000        10.000
# 1456        10.000        10.000        10.000
# 1457          None          None          None
# 1458          None          None          None
# 1459  -137.297.372  -137.984.298  -132.284.830
#
# [1460 rows x 11 columns]

# %%
df['CAPITOL'].value_counts()
# Out:
# CAPITOL
# 6501    82
# 8401    77
# 6801    73
# 8301    71
# 6101    69
#         ..
# 0004     1
# 1000     1
# 4501     1
# 4801     1
# 9901     1
# Name: count, Length: 67, dtype: int64

# %%
df[df['CAPITOL'] == '6501']
# Out:
#     CAPITOL SUBCAPITOL PARAGRAF GRUPA ARTICOL ALINEAT  \
# 643    6501       None     None  None    None    None
# 644    6501       None     None  None    None    None
# 645    6501       None     None  None    None    None
# 646    6501                        01    None    None
# 647    6501                        01    None    None
# ..      ...        ...      ...   ...     ...     ...
# 720    6501         11       30  None    None    None
# 721    6501         13     None  None    None    None
# 722    6501         13     None  None    None    None
# 723    6501         50     None  None    None    None
# 724    6501         50     None  None    None    None
#
#                                         DENUMIRE PROGRAM_2025 ESTIMARI2026  \
# 643                                   INVATAMANT         None         None
# 644                      I.Credite de angajament   71.891.918   57.643.428
# 645                          II.Credite bugetare   60.295.342   63.585.958
# 646                           CHELTUIELI CURENTE         None         None
# 647                      I.Credite de angajament   71.412.372   57.429.188
# ..                                           ...          ...          ...
# 720                          II.Credite bugetare      590.594         None
# 721                     Invatamant anteprescolar         None         None
# 722                          II.Credite bugetare      576.345         None
# 723   Alte cheltuieli in domeniul invatamantului         None         None
# 724                          II.Credite bugetare   10.336.701         None
#
#     ESTIMARI2027 ESTIMARI2028
# 643         None         None
# 644   59.714.423   62.766.716
# 645   59.617.088   62.588.053
# 646         None         None
# 647   59.406.534   62.459.461
# ..           ...          ...
# 720         None         None
# 721         None         None
# 722         None         None
# 723         None         None
# 724         None         None
#
# [82 rows x 11 columns]

# %%
temp = parse_large_xml(file_path, target_elements)

# %%
temp[0]
# Out:
# {'TITLU_RAPORT': 'BUGETUL DE STAT',
#  'ANEXA': 'Anexa nr.1',
#  'COD_ORDONATOR': '00',
#  'ORDONATOR': 'Total',
#  'CAPITOL': '0001',
#  'SUBCAPITOL': '01',
#  'PARAGRAF': None,
#  'GRUPA': None,
#  'ARTICOL': None,
#  'ALINEAT': None,
#  'DENUMIRE': 'VENITURI - TOTAL',
#  'PROGRAM_2025': '357.353.033',
#  'ESTIMARI2026': '349.169.360',
#  'ESTIMARI2027': '349.399.128',
#  'ESTIMARI2028': '367.798.364'}

# %%
temp[1]
# Out:
# {'TITLU_RAPORT': 'BUGETUL DE STAT',
#  'ANEXA': 'Anexa nr.1',
#  'COD_ORDONATOR': '00',
#  'ORDONATOR': 'Total',
#  'CAPITOL': '0002',
#  'SUBCAPITOL': '01',
#  'PARAGRAF': '  ',
#  'GRUPA': None,
#  'ARTICOL': None,
#  'ALINEAT': None,
#  'DENUMIRE': 'I.VENITURI CURENTE',
#  'PROGRAM_2025': '278.999.496',
#  'ESTIMARI2026': '296.761.619',
#  'ESTIMARI2027': '317.534.856',
#  'ESTIMARI2028': '339.093.921'}
